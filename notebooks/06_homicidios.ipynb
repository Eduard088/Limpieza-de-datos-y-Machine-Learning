# %% [markdown]
# ## Cargamos las Librerías:

# %%
import polars as pl
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import pandas as pd

# %% [markdown]
# ## Cargamos el Conjunto de Datos:

# %%
homicidios = pl.read_csv('~/homicidios/data/final/homicidios_final.csv')
homicidios

# %% [markdown]
# ## Enraízamos el Proyecto:

# %%
import sys, os
sys.path.append(os.path.abspath(".."))

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Importamos las Funciones Modulares:

# %%
import modules.eliminar_variables
from modules.eliminar_variables import variables_ml_pca
from modules.eliminar_variables import eliminar_variables

# %% [markdown]
# ## Eliminamos las Variables:

# %%
homicidios = eliminar_variables(df= homicidios, variables= variables_ml_pca)

# %%
homicidios

# %% [markdown]
# ## Escalación de Datos:

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaaler = StandardScaler()
df_homicidios_scaled = scaaler.fit_transform(homicidios.drop('estado_defuncion_registrada'))

print(df_homicidios_scaled)
