# %%
import polars as pl
import os
import sys

# %%
sys.path.append(os.path.abspath(".."))

# %%
from modules.aplicar_catalogos_1 import aplicar_catalogos_polars

# %%
ruta_catalogos = os.path.expanduser("~/homicidios/data/codes/")
homicidios = pl.read_csv('~/homicidios/data/raw/homicidios.csv')

# %%
homicidios
# Out:
# shape: (799_869, 74)
# ┌───────────┬───────────┬────────────┬───────────┬───┬───────────┬───────────┬─────────┬───────────┐
# │ ent_regis ┆ mun_regis ┆ tloc_regis ┆ loc_regis ┆ … ┆ mun_ocule ┆ loc_ocule ┆ razon_m ┆ dis_re_oa │
# │ ---       ┆ ---       ┆ ---        ┆ ---       ┆   ┆ s         ┆ s         ┆ ---     ┆ x         │
# │ i64       ┆ i64       ┆ i64        ┆ i64       ┆   ┆ ---       ┆ ---       ┆ i64     ┆ ---       │
# │           ┆           ┆            ┆           ┆   ┆ i64       ┆ i64       ┆         ┆ i64       │
# ╞═══════════╪═══════════╪════════════╪═══════════╪═══╪═══════════╪═══════════╪═════════╪═══════════╡
# │ 1         ┆ 1         ┆ 15         ┆ 1         ┆ … ┆ 888       ┆ 8888      ┆ 0       ┆ 999       │
# │ 1         ┆ 1         ┆ 15         ┆ 1         ┆ … ┆ 888       ┆ 8888      ┆ 0       ┆ 999       │
# │ 1         ┆ 1         ┆ 15         ┆ 1         ┆ … ┆ 888       ┆ 8888      ┆ 0       ┆ 999       │
# ...

# %%
aplicar_catalogos_polars(homicidios, ruta_catalogos)
# Out:
# [OK] Catálogo aplicado: cond_act.csv
# [OK] Catálogo aplicado: causa_def.csv
# [OK] Catálogo aplicado: usonecrops.csv
# [OK] Catálogo aplicado: asist_medi.csv
# [OK] Catálogo aplicado: sexo.csv
# [OK] Catálogo aplicado: sem_gest.csv
# [OK] Catálogo aplicado: edad_agru.csv
# [OK] Catálogo aplicado: natviole.csv
# [OK] Catálogo aplicado: derechohab.csv
# [OK] Catálogo aplicado: par_agre.csv
# [OK] Catálogo aplicado: tipo_defun.csv
# [OK] Catálogo aplicado: vio_fami.csv
# [OK] Catálogo aplicado: minutos.csv
# [OK] Catálogo aplicado: nacesp_cve.csv
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
